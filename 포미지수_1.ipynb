# %% [markdown]
# ####**4) 포미지수**

# %% [markdown]
# #####**forme1**

# %%
#포미지수

# %%
card0=data[data['카드소비금액']==0]
card0

#카드 소비 금액이 0인 사람이 494명이 나옴
#전반적인 소비가 없으면 제외하고 아니면 대체 값(ex 평균 등을 넣어 대체하고자 함)
# Out:
#         기준시점  아파트단지코드  라이프스테이지  요식이용금액  유흥이용금액  백화점이용금액  대형할인점이용금액  소형유통점이용금액  \
# 1329    201Q  A103562        2  485000       0        0          0     410000
# 2785    201Q  A108212        4       0       0        0          0          0
# 3108    201Q  A108506        5       0       0        0          0          0
# 3857    201Q  A111057        4       0       0        0          0          0
# 4965    201Q  A113419        5       0       0        0          0          0
# ...      ...      ...      ...     ...     ...      ...        ...        ...
# 419357  204Q    A5587        4       0       0        0          0          0
# 421779  204Q   A64463        4       0       0        0          0          0
# 422020  204Q   A64588        5       0       0        0          0      13000
# 431280  204Q   A89027        2       0       0        0          0          0
# 433681  204Q   A95786        4  358000       0    32000      59000     409000
#
# ...

# %%
card0=card0.iloc[:,3:26]
card0

#금액과 관련된 columns만 저장
# Out:
#         요식이용금액  유흥이용금액  백화점이용금액  대형할인점이용금액  소형유통점이용금액  의류/잡화이용금액  \
# 1329    485000       0        0          0     410000          0
# 2785         0       0        0          0          0          0
# 3108         0       0        0          0          0          0
# 3857         0       0        0          0          0          0
# 4965         0       0        0          0          0          0
# ...        ...     ...      ...        ...        ...        ...
# 419357       0       0        0          0          0          0
# 421779       0       0        0          0          0          0
# 422020       0       0        0          0      13000          0
# 431280       0       0        0          0          0          0
# 433681  358000       0    32000      59000     409000    1013000
#
#         스포츠/문화/레저이용금액  숙박이용금액  국내여행이용금액  교통이용금액  ...  의료이용금액  가전/가구이용금액  \
# 1329           177000       0         0       0  ...    6000          0
# ...

# %%
card1=data[data["카드소비금액"]!=0]

# %%
forme=data[['유흥이용금액','스포츠/문화/레저이용금액', '미용이용금액', '교육/학원이용금액']]

# %%
forme_corr=forme.corr()

# %%
sns.heatmap(forme_corr, cmap="PuBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
#(1) 유흥 이용

result2=data['유흥이용금액']/data['카드소비금액']
result2=result2.to_frame()
result2.columns=['유흥이용비율']
result2
# Out:
#         유흥이용비율
# 0      0.92784
# 1      1.74442
# 2      0.00000
# 3      1.55440
# 4      0.09800
# ...        ...
# 434699 0.05618
# 434700 0.00000
# 434701 0.16429
# 434702 1.85061
# 434703 0.86569
#
# [434704 rows x 1 columns]

# %%
result2=result2[result2.유흥이용비율!=0]
result2.describe()

# 유흥이용비율이 0인 사람 제거-> 223376명이 유흥에 0원 사용-> 따로 지수 0 -> 유흥에 관심 없는 사람: 51.44%
# 나머지 약 48.56%가 유흥에 소비를 하는 사람
# 분석 인구 절반 이상이 유흥에 0원을 사용
# 옛날엔 유흥에 사용하지 않는 사람들이면 유흥 관련 업종 마케팅의 대상이 아니었음-> 초개인화 맞춤 마케팅 제안
# 새로운 51.44%의 잠재적 소비자로 만들 수 있음
# Out:
#             유흥이용비율
# count 210849.00000
# mean           inf
# std            NaN
# min        0.00049
# 25%        0.29019
# 50%        0.79382
# 75%        2.01586
# max            inf

# %%
result2.sort_values("유흥이용비율")
# Out:
#         유흥이용비율
# 410685 0.00049
# 316989 0.00053
# 258796 0.00072
# 303538 0.00087
# 344253 0.00087
# ...        ...
# 419357     NaN
# 421779     NaN
# 422020     NaN
# 431280     NaN
# 433681     NaN
#
# [211328 rows x 1 columns]

# %%
result2 = result2.dropna()
result2
# Out:
#         유흥이용비율
# 0      0.92784
# 1      1.74442
# 3      1.55440
# 4      0.09800
# 5      1.86097
# ...        ...
# 434698 1.04603
# 434699 0.05618
# 434701 0.16429
# 434702 1.85061
# 434703 0.86569
#
# [210849 rows x 1 columns]
