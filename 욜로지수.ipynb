# %% [markdown]
# ####**6) 욜로지수**

# %%
#yolo지수

# %%
data
# Out:
#         기준시점  아파트단지코드  라이프스테이지    요식이용금액  유흥이용금액  백화점이용금액  대형할인점이용금액  \
# 0       201Q  A100064        2   3750000  180000   449000    4630000
# 1       201Q  A100064        5   1034000   86000  1433000     509000
# 2       201Q  A100064        4   3675000       0   330000    1386000
# 3       201Q  A100064        1   7605000  240000  1610000     917000
# 4       201Q  A100064        3  16381000   54000  1010000    7459000
# ...      ...      ...      ...       ...     ...      ...        ...
# 434699  204Q   A99978        5   2635000    3000  1074000    1518000
# 434700  204Q   A99978        4   5486000       0   215000    2913000
# 434701  204Q   A99978        3   9482000   38000  3570000    5150000
# 434702  204Q   A99978        2   3705000  166000  5798000    1148000
# 434703  204Q   A99978        1   6361000  136000   966000    1645000
#
#         소형유통점이용금액  의류/잡화이용금액  스포츠/문화/레저이용금액  ...  평일이동거리  휴일이동거리  네비이용횟수  \
# ...

# %%
yolo=data[['신용대출잔액','주택담보대출잔액','특급호텔이용금액','백화점이용금액','총자산평가금액', '라이프스테이지', '국내여행이용금액','숙박이용금액',"해외여행이용금액","카드소비금액","유흥이용금액"]]
yolo["여행이용금액"]=yolo["해외여행이용금액"]+yolo['국내여행이용금액']
yolo["자산대비소비"]=yolo['카드소비금액']/yolo['총자산평가금액']
yolo['유흥지수']=yolo['유흥이용금액']/yolo['카드소비금액']
yolo["자산대비대출"]=(yolo["신용대출잔액"]+yolo['주택담보대출잔액'])/yolo['총자산평가금액']
yolo["욜로지수"]=0
yolo["욜로지수_H"]=0
yolo
# Out:
# <ipython-input-182-0984e47ca2fa>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-182-0984e47ca2fa>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-182-0984e47ca2fa>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
condition_0=yolo[yolo.카드소비금액==0].index
yolo.drop(condition_0, inplace=True)
# Out:
# <ipython-input-183-abbefe3b3f3a>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo.reset_index(drop=True, inplace=True)
yolo
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 1        59472    584384         0  1433000   7744560        5         0
# 2        57629    320850     30000   330000  10609180        4         0
# 3       146806    312238         0  1610000  11066770        1         0
# 4       794672   1997926     70000  1010000  27984730        3     69000
# ...        ...       ...       ...      ...       ...      ...       ...
# 434205   17629    153896         0  1074000  11207130        5         0
# 434206  221664    474407         0   215000  16956640        4         0
# 434207  373270    944717    218000  3570000  17045770        3     75000
# 434208  318836    128594         0  5798000   5612160        2         0
# 434209  264705         0     40000   966000  12884650        1         0
#
#         숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# ...

# %%
yolo=pd.DataFrame(yolo)

# %%
np.count_nonzero(yolo.여행이용금액)/434210*100
# Out:
# 39.678266276686394

# %%
np.count_nonzero(yolo.국내여행이용금액)/434210*100
# Out:
# 36.52863821653117

# %%
condition=(yolo.여행이용금액>20000)
yolo_non=yolo.loc[condition ]  
condition2=(yolo.여행이용금액<=20000)
yolo_zeros=yolo.loc[condition2]

                                    #여행경험자들만 모아놓은 데이터

# %%
print(len(yolo_non) ,len(yolo_zeros),len(yolo)   )
# Out:
# 162772 271438 434210

# %%
yolo_non
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 4       794672   1997926     70000  1010000  27984730        3     69000
# 5       632030   1020437    395000   571000  12977490        3    834000
# 6       117292    161822      7000   930000   5503040        2    142000
# 8        42357    211075     26000   858000  11031250        1         0
# ...        ...       ...       ...      ...       ...      ...       ...
# 434194  233638    522823      8000   814000  12532390        1    461000
# 434197  596496    693746         0        0   7564790        3    204000
# 434199  257725    266130         0  2925000  11361790        1    562000
# 434203  491378    649552         0  1607000   8535220        2    456000
# 434207  373270    944717    218000  3570000  17045770        3     75000
#
#         숙박이용금액  해외여행이용금액  카드소비금액   유흥이용금액  여행이용금액  자산대비소비     유흥지수  자산대비대출  \
# ...

# %%
print(len(yolo_non[yolo_non.라이프스테이지==1])/len(yolo[yolo.라이프스테이지==1]),
len(yolo_non[yolo_non.라이프스테이지==2])/len(yolo[yolo.라이프스테이지==2]),
len(yolo_non[yolo_non.라이프스테이지==3])/len(yolo[yolo.라이프스테이지==3]),
len(yolo_non[yolo_non.라이프스테이지==4])/len(yolo[yolo.라이프스테이지==4]),
len(yolo_non[yolo_non.라이프스테이지==5])/len(yolo[yolo.라이프스테이지==5]))

## 코로나의 영향에도 라이프스테이지 1,3은 절반이상이 여행을 갔고, 5는 여행경험률이 현저히 낮음  
## 실버세대는 코로나의 영향으로 여행을 삼가했을 가능성이 크다.
# Out:
# 0.5380974541162049 0.37064035252203265 0.5024847962240174 0.33286563316336426 0.12086373264297481

# %%
yolo_non["욜로지수"]=(yolo_non.여행이용금액/yolo_non.카드소비금액)*1000
# Out:
# <ipython-input-192-7bde29d28208>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo_non["욜로지수_H"]=(1/2*(yolo_non.욜로지수)+1/2*(yolo_non.숙박이용금액/yolo_non.카드소비금액)*1000)
# Out:
# <ipython-input-193-49f5a0ac1d72>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo_non.욜로지수.describe()
# Out:
# count    162772.00000
# mean       2863.28496
# std        9254.88351
# min           7.50236
# 25%         432.89680
# 50%        1057.06765
# 75%        2671.51416
# max     1570000.00000
# Name: 욜로지수, dtype: float64

# %%
yolo_non.욜로지수_H.describe()
# Out:
# count   162772.00000
# mean      2094.31846
# std       4889.22008
# min         12.32033
# 25%        582.18802
# 50%       1148.16404
# 75%       2250.97189
# max     785000.00000
# Name: 욜로지수_H, dtype: float64

# %%
yolo_non.head()    ## 욜로지수_H와 욜로지수간의 차이가 너무 크면 호캉스족으로 분류, 작은 차이는 
                   ## 숙박에 큰 돈을 쓰는 타입으로 분류할 수 있다.
# Out:
#    신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  숙박이용금액  \
# 0  388157   1191577    392000   449000   9607630        2    125000  392000
# 4  794672   1997926     70000  1010000  27984730        3     69000  425000
# 5  632030   1020437    395000   571000  12977490        3    834000  546000
# 6  117292    161822      7000   930000   5503040        2    142000   42000
# 8   42357    211075     26000   858000  11031250        1         0  365000
#
#    해외여행이용금액  카드소비금액   유흥이용금액  여행이용금액  자산대비소비     유흥지수  자산대비대출       욜로지수  \
# 0         0  194000   180000  125000 0.02019  0.92784 0.16442  644.32990
# 4         0  551000    54000   69000 0.01969  0.09800 0.09979  125.22686
# 5     43000  182700   340000  877000 0.01408  1.86097 0.12733 4800.21894
# 6         0   94200    21000  142000 0.01712  0.22293 0.05072 1507.43100
# 8    231000  132500  1425000  231000 0.01201 10.75472 0.02297 1743.39623
#
#       욜로지수_H
# 0 1332.47423
# 4  448.27586
# 5 3894.36234
# ...

# %%
## 소비를 적극적으로 하는 세대 -> 실제로 여행사의 주고객은 30대 기혼남성으로 어린이, 청소년 자녀가 있는 세대

a=yolo_non.groupby("라이프스테이지")["카드소비금액"].sum()/yolo_non.groupby('라이프스테이지')["카드소비금액"].count()
b=yolo_non.groupby("라이프스테이지")["여행이용금액"].sum()/yolo_non.groupby('라이프스테이지')["카드소비금액"].count()

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.title("라이프스테이지별 평균 카드소비금액(천원)", fontsize=20)
a.plot(kind='pie', autopct="%1.1f%%", textprops={'fontsize':20},
       colors=['chocolate','bisque','cadetblue','lightpink','gold'])

plt.xlabel("라이프스테이지별", fontsize=20)
plt.ylabel("평균카드소비금액", fontsize=20)

plt.subplot(1,2,2)
plt.title("라이프스테이지별 평균 여행이용금액(원)", fontsize=20)

b.plot(kind='pie', autopct="%1.1f%%", textprops={'fontsize':20}, colors=['chocolate','bisque','cadetblue','lightpink','gold'])
plt.xlabel("라이프스테이지별", fontsize=20)
plt.ylabel("평균여행이용금액", fontsize=20)
plt.show()

# %%
yolo_non["욜로지수"]=np.log(yolo_non["욜로지수"])
yolo_non["욜로지수_H"]=np.log(yolo_non["욜로지수_H"])
yolo_non.head()
# Out:
# <ipython-input-198-495480adaba7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-198-495480adaba7>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  숙박이용금액  \
# 0  388157   1191577    392000   449000   9607630        2    125000  392000
# 4  794672   1997926     70000  1010000  27984730        3     69000  425000
# 5  632030   1020437    395000   571000  12977490        3    834000  546000
# ...

# %%
yolo_non["욜로지수"].describe()
# Out:
# count   162772.00000
# mean         6.98529
# std          1.36434
# min          2.01522
# 25%          6.07050
# 50%          6.96325
# 75%          7.89040
# max         14.26659
# Name: 욜로지수, dtype: float64

# %%
sns.distplot(yolo_non.욜로지수, bins=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='욜로지수', ylabel='Density'>

# %%
yolo_non.욜로지수.describe(percentiles=[.10,.30,.75,.90])
# Out:
# count   162772.00000
# mean         6.98529
# std          1.36434
# min          2.01522
# 10%          5.21957
# 30%          6.27304
# 50%          6.96325
# 75%          7.89040
# 90%          8.76449
# max         14.26659
# Name: 욜로지수, dtype: float64

# %%
sns.distplot(yolo_non.욜로지수_H, bins=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='욜로지수_H', ylabel='Density'>

# %%
yolo_non.욜로지수_H.describe(percentiles=[.10,.30,.75,.90])  ##라이프스테이지1에 부여해야 할 욜로지수 범위,  
                                                            ## 매우절약형, 절약형, 평균, 욜로형, 매우욜로형
# Out:
# count   162772.00000
# mean         7.04144
# std          1.06637
# min          2.51125
# 10%          5.69923
# 30%          6.52144
# 50%          7.04592
# 75%          7.71912
# 90%          8.36658
# max         13.57344
# Name: 욜로지수_H, dtype: float64

# %%
df=yolo_non.copy()
df
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 4       794672   1997926     70000  1010000  27984730        3     69000
# 5       632030   1020437    395000   571000  12977490        3    834000
# 6       117292    161822      7000   930000   5503040        2    142000
# 8        42357    211075     26000   858000  11031250        1         0
# ...        ...       ...       ...      ...       ...      ...       ...
# 434194  233638    522823      8000   814000  12532390        1    461000
# 434197  596496    693746         0        0   7564790        3    204000
# 434199  257725    266130         0  2925000  11361790        1    562000
# 434203  491378    649552         0  1607000   8535220        2    456000
# 434207  373270    944717    218000  3570000  17045770        3     75000
#
#         숙박이용금액  해외여행이용금액  카드소비금액   유흥이용금액  여행이용금액  자산대비소비     유흥지수  자산대비대출  \
# ...

# %%
df["욜로지수"][(df.욜로지수<df['욜로지수'].quantile(.10))]=1
df["욜로지수"][(df.욜로지수>=df['욜로지수'].quantile(.10))&(df.욜로지수<df['욜로지수'].quantile(.30))]=2
df["욜로지수"][(df.욜로지수>=df['욜로지수'].quantile(.30))&(df.욜로지수<df['욜로지수'].quantile(.75))]=3
df["욜로지수"][(df.욜로지수>=df['욜로지수'].quantile(.75))&(df.욜로지수<df['욜로지수'].quantile(.90))]=4
df["욜로지수"][(df.욜로지수>=df['욜로지수'].quantile(.90))]=5
# Out:
# <ipython-input-205-11036a3ec383>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-205-11036a3ec383>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-205-11036a3ec383>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-205-11036a3ec383>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df["욜로지수_H"][(df.욜로지수_H< df['욜로지수_H'].quantile(.10))]=1
df["욜로지수_H"][(df.욜로지수_H>=df['욜로지수_H'].quantile(.10))&(df.욜로지수_H<df['욜로지수_H'].quantile(.30))]=2
df["욜로지수_H"][(df.욜로지수_H>= df['욜로지수_H'].quantile(.30))&(df.욜로지수_H<df['욜로지수_H'].quantile(.75))]=3
df["욜로지수_H"][(df.욜로지수_H>=df['욜로지수_H'].quantile(.75))&(df.욜로지수_H<df['욜로지수_H'].quantile(.90))]=4
df["욜로지수_H"][(df.욜로지수_H>=df['욜로지수_H'].quantile(.90))]=5

df
# Out:
# <ipython-input-206-2e42ae65c487>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-206-2e42ae65c487>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-206-2e42ae65c487>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-206-2e42ae65c487>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_corr=df.corr()                          
                                                 
sns.heatmap(df_corr, cmap="PuBu", annot=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:332: UserWarning:
#
# Glyph 8722 (\N{MINUS SIGN}) missing from current font.
# <AxesSubplot:>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning:
#
# Glyph 8722 (\N{MINUS SIGN}) missing from current font.

# %%
df.loc[abs(df.욜로지수-df.욜로지수_H)!=0]    ##아마도 호캉스 즐기는, 또는 여행에 숙박비용 아끼는 타입
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 4       794672   1997926     70000  1010000  27984730        3     69000
# 17      682180   3031291    222000  1939000  40510480        4   2119000
# 32      115397    109890         0        0   4337140        3         0
# 55      267935   1287650         0   618000  39965660        5    289000
# 79      447405     96256         0  5162000   6169940        2     47000
# ...        ...       ...       ...      ...       ...      ...       ...
# 434193  659695    865152     44000  3614000  11307930        2    297000
# 434194  233638    522823      8000   814000  12532390        1    461000
# 434199  257725    266130         0  2925000  11361790        1    562000
# 434203  491378    649552         0  1607000   8535220        2    456000
# 434207  373270    944717    218000  3570000  17045770        3     75000
#
#         숙박이용금액  해외여행이용금액  카드소비금액   유흥이용금액   여행이용금액  자산대비소비     유흥지수  자산대비대출  \
# ...

# %%
df.groupby("욜로지수_H").mean()/df.groupby("욜로지수_H") .count()
# Out:
#           신용대출잔액  주택담보대출잔액  특급호텔이용금액   백화점이용금액    총자산평가금액  라이프스테이지  국내여행이용금액  \
# 욜로지수_H
# 1.00000 53.54030 118.49030   0.72126 171.71372 1064.93164  0.00019   5.28099
# 2.00000 35.92277  79.22594   1.80414 126.61972  744.83442  0.00009   7.12382
# 3.00000 14.57661  31.40557   2.43049  67.12674  366.78111  0.00003   6.47085
# 4.00000 29.08287  63.61930   9.18824 164.54642  919.34481  0.00009  31.29502
# 5.00000 21.28152  48.17436   9.86042 158.16649  879.91231  0.00014  52.26065
#
#           숙박이용금액  해외여행이용금액   카드소비금액   유흥이용금액    여행이용금액  자산대비소비    유흥지수  \
# 욜로지수_H
# 1.00000  5.71541   0.73683 30.59347 18.73132   6.01782 0.00000 0.00004
# 2.00000 10.47494   1.37518 19.23885 12.49324   8.49900 0.00000 0.00002
# 3.00000  9.94443   2.52880  7.60299  5.62382   8.99965 0.00000 0.00001
# 4.00000 32.65684  29.85084 15.63496 14.96884  61.14586 0.00000 0.00005
# 5.00000 33.22711  82.28607 12.41577 15.16997 134.54672 0.00000 0.00010
#
#          자산대비대출    욜로지수
# 욜로지수_H
# ...

# %%
yolo_zeros["욜로지수"]=1
yolo_zeros["욜로지수_H"]=1/2+(yolo_zeros.숙박이용금액/yolo_zeros.카드소비금액*1000)##평균값 부여
# Out:
# <ipython-input-210-6ed73c69974a>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-210-6ed73c69974a>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo_zeros.욜로지수_H.describe()
# Out:
# count   271438.00000
# mean       838.79141
# std       3779.09701
# min          0.50000
# 25%          0.50000
# 50%          0.50000
# 75%        606.08536
# max     700000.50000
# Name: 욜로지수_H, dtype: float64

# %%
qq=yolo_zeros.욜로지수_H
qqq=qq.values.reshape(-1,1)

from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
qq_scaled=sc.fit_transform(qqq)

# %%
qq_scaled
# Out:
# array([[0.        ],
#        [0.00025484],
#        [0.00101776],
#        ...,
#        [0.00034361],
#        [0.        ],
#        [0.00255524]])

# %%
yolo_zeros["욜로지수_H"]=qq_scaled*10000+1
# Out:
# <ipython-input-214-1331e944ec64>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo_zeros["욜로지수_H"]
# Out:
# 1         1.00000
# 2         3.54842
# 3        11.17765
# 7         1.00000
# 9         1.00000
#            ...
# 434204   42.84100
# 434205    1.00000
# 434206    4.43613
# 434208    1.00000
# 434209   26.55242
# Name: 욜로지수_H, Length: 271438, dtype: float64

# %%
yolo_zeros.욜로지수_H=np.log(yolo_zeros["욜로지수_H"]*100)
# Out:
# <ipython-input-216-f4b746d81a98>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
yolo_zeros.욜로지수_H.describe()
# Out:
# count   271438.00000
# mean         5.68978
# std          1.49880
# min          4.60517
# 25%          4.60517
# 50%          4.60517
# 75%          6.87225
# max         13.81561
# Name: 욜로지수_H, dtype: float64

# %%
sns.distplot(yolo_zeros.욜로지수_H, bins=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='욜로지수_H', ylabel='Density'>

# %%
yolo_zeros.욜로지수_H.describe(percentiles=[.59,.69,.80,.90])
# Out:
# count   271438.00000
# mean         5.68978
# std          1.49880
# min          4.60517
# 50%          4.60517
# 59%          4.81018
# 69%          6.38590
# 80%          7.23759
# 90%          8.04756
# max         13.81561
# Name: 욜로지수_H, dtype: float64

# %%
dff=yolo_zeros.copy()
dff["욜로지수_H"][(yolo_zeros.욜로지수_H< yolo_zeros.욜로지수.quantile(.59))]=1
dff["욜로지수_H"][(yolo_zeros.욜로지수_H>= yolo_zeros.욜로지수.quantile(.59))&(yolo_zeros.욜로지수_H<    yolo_zeros.욜로지수.quantile(.69))]=2
dff["욜로지수_H"][(yolo_zeros.욜로지수_H>=   yolo_zeros.욜로지수.quantile(.69))&(yolo_zeros.욜로지수_H<yolo_zeros.욜로지수.quantile(.79))]=3
dff["욜로지수_H"][(yolo_zeros.욜로지수_H>=yolo_zeros.욜로지수.quantile(.79))&(yolo_zeros.욜로지수_H< yolo_zeros.욜로지수.quantile(.89))]=4
dff["욜로지수_H"][(yolo_zeros.욜로지수_H>= yolo_zeros.욜로지수.quantile(.89))]=5
# Out:
# <ipython-input-220-2b43ab9f98e0>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-220-2b43ab9f98e0>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-220-2b43ab9f98e0>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-220-2b43ab9f98e0>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dff
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 1        59472    584384         0  1433000   7744560        5         0
# 2        57629    320850     30000   330000  10609180        4         0
# 3       146806    312238         0  1610000  11066770        1         0
# 7       273192    577398         0  1426000   9195890        4         0
# 9        25603    210019         0    79000   9564770        5         0
# ...        ...       ...       ...      ...       ...      ...       ...
# 434204  657269    318461         0   344000  10399630        1         0
# 434205   17629    153896         0  1074000  11207130        5         0
# 434206  221664    474407         0   215000  16956640        4         0
# 434208  318836    128594         0  5798000   5612160        2         0
# 434209  264705         0     40000   966000  12884650        1         0
#
#         숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# ...

# %%
df
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 4       794672   1997926     70000  1010000  27984730        3     69000
# 5       632030   1020437    395000   571000  12977490        3    834000
# 6       117292    161822      7000   930000   5503040        2    142000
# 8        42357    211075     26000   858000  11031250        1         0
# ...        ...       ...       ...      ...       ...      ...       ...
# 434194  233638    522823      8000   814000  12532390        1    461000
# 434197  596496    693746         0        0   7564790        3    204000
# 434199  257725    266130         0  2925000  11361790        1    562000
# 434203  491378    649552         0  1607000   8535220        2    456000
# 434207  373270    944717    218000  3570000  17045770        3     75000
#
#         숙박이용금액  해외여행이용금액  카드소비금액   유흥이용금액  여행이용금액  자산대비소비     유흥지수  자산대비대출  \
# ...

# %%
yolo_result=pd.concat([df, dff], )
yolo_result=yolo_result.sort_index()
yolo_result
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 1        59472    584384         0  1433000   7744560        5         0
# 2        57629    320850     30000   330000  10609180        4         0
# 3       146806    312238         0  1610000  11066770        1         0
# 4       794672   1997926     70000  1010000  27984730        3     69000
# ...        ...       ...       ...      ...       ...      ...       ...
# 434205   17629    153896         0  1074000  11207130        5         0
# 434206  221664    474407         0   215000  16956640        4         0
# 434207  373270    944717    218000  3570000  17045770        3     75000
# 434208  318836    128594         0  5798000   5612160        2         0
# 434209  264705         0     40000   966000  12884650        1         0
#
#         숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# ...

# %%
# 라이프스테이지별 분석
yolo_1=df[df["라이프스테이지"]==1]
yolo_2=df[df["라이프스테이지"]==2]
yolo_3=df[df["라이프스테이지"]==3]
yolo_4=df[df["라이프스테이지"]==4]
yolo_5=df[df["라이프스테이지"]==5]

# %%
#스케일링 후에 비교하기
aa=yolo_1.욜로지수.sum()/len(yolo_1)
bb=yolo_2.욜로지수.sum()/len(yolo_2)
cc=yolo_3.욜로지수.sum()/len(yolo_3)
dd=yolo_4.욜로지수.sum()/len(yolo_4) 
ee=yolo_5.욜로지수.sum()/len(yolo_5)

print(aa,bb,cc,dd,ee)   

## 실버세대는 여행경험자수는 적지만 욜로지수는 제일 높다
## 부양가족이 있는 라이프스테이지들은 돈을 아끼려는 심리가 많고
## 싱글과 실버세대가 여행을 많은 비중으로 하고 사는 것으로 보인다 

## 라이프스테이지보다 개인별 격차가 더 클 것 같다
## 표로 표현하기
# Out:
# 3.167397907526156 3.0018023145513184 2.6543680989906746 2.8654557916381083 3.3020153831175154

# %%
yolo_result.iloc[43403]
# Out:
# 신용대출잔액       258467.00000
# 주택담보대출잔액      84669.00000
# 특급호텔이용금액          0.00000
# 백화점이용금액      313000.00000
# 총자산평가금액    11333080.00000
# 라이프스테이지           1.00000
# 국내여행이용금액      31000.00000
# 숙박이용금액       191000.00000
# 해외여행이용금액     244000.00000
# 카드소비금액       199100.00000
# 유흥이용금액       138000.00000
# 여행이용금액       275000.00000
# 자산대비소비            0.01757
# 유흥지수              0.69312
# 자산대비대출            0.03028
# 욜로지수              3.00000
# 욜로지수_H            3.00000
# Name: 43403, dtype: float64

# %%
aaa=yolo_result.loc[ (yolo_result['욜로지수']==2)&(yolo_result['욜로지수_H'] ==3)]
aaa.tail()    ##여행에는 돈 적게 쓰는 편이지만  숙박비용은 많이 나가는, 호캉스 즐기는 타입
# Out:
#          신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 434138   812500   1480451         0  2691000  25630590        2    138000
# 434146   521646   3841660    490000  9332103  52229690        4    153000
# 434151  1330174   2600926    490000  7465000  64133380        4    164000
# 434153   841495   1290936    148000  3796000  16754440        2     94000
# 434207   373270    944717    218000  3570000  17045770        3     75000
#
#          숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# 434138  1015000         0  401900       0  138000 0.01568 0.00000 0.08946
# 434146  1132000         0  404300  191000  153000 0.00774 0.47242 0.08354
# 434151  1169000         0  617800  410000  164000 0.00963 0.66365 0.06130
# 434153   248000         0  241800       0   94000 0.01443 0.00000 0.12728
# 434207   253000         0  231300   38000   75000 0.01357 0.16429 0.07732
#
#           욜로지수  욜로지수_H
# 434138 2.00000 3.00000
# 434146 2.00000 3.00000
# ...

# %%
bbb=yolo_result.loc[ abs(yolo_result['욜로지수'] -yolo_result['욜로지수_H']) !=0]
bbb
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 1        59472    584384         0  1433000   7744560        5         0
# 2        57629    320850     30000   330000  10609180        4         0
# 3       146806    312238         0  1610000  11066770        1         0
# 4       794672   1997926     70000  1010000  27984730        3     69000
# 7       273192    577398         0  1426000   9195890        4         0
# ...        ...       ...       ...      ...       ...      ...       ...
# 434205   17629    153896         0  1074000  11207130        5         0
# 434206  221664    474407         0   215000  16956640        4         0
# 434207  373270    944717    218000  3570000  17045770        3     75000
# 434208  318836    128594         0  5798000   5612160        2         0
# 434209  264705         0     40000   966000  12884650        1         0
#
#         숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# ...

# %%
len(aaa), len(bbb)
# Out:
# (10767, 338515)

# %%
yolo_result
# Out:
#         신용대출잔액  주택담보대출잔액  특급호텔이용금액  백화점이용금액   총자산평가금액  라이프스테이지  국내여행이용금액  \
# 0       388157   1191577    392000   449000   9607630        2    125000
# 1        59472    584384         0  1433000   7744560        5         0
# 2        57629    320850     30000   330000  10609180        4         0
# 3       146806    312238         0  1610000  11066770        1         0
# 4       794672   1997926     70000  1010000  27984730        3     69000
# ...        ...       ...       ...      ...       ...      ...       ...
# 434205   17629    153896         0  1074000  11207130        5         0
# 434206  221664    474407         0   215000  16956640        4         0
# 434207  373270    944717    218000  3570000  17045770        3     75000
# 434208  318836    128594         0  5798000   5612160        2         0
# 434209  264705         0     40000   966000  12884650        1         0
#
#         숙박이용금액  해외여행이용금액  카드소비금액  유흥이용금액  여행이용금액  자산대비소비    유흥지수  자산대비대출  \
# ...

# %%
yolo_result.to_csv("./YOLO.csv", index=False)
